# %% [markdown]
# <a href="https://colab.research.google.com/github/taegeonyu/hds5210-2023/blob/main/week09/module38-pandas-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating Pandas dataframes

# %%
import pandas as pd

# %%
names = [
    ['Paul','Boal','E'],
    ['Eric','Westhus','D'],
    ['Bill','Jones','A']
    ]

# %%
pd.DataFrame(names)
# Out:
#       0        1  2
# 0  Paul     Boal  E
# 1  Eric  Westhus  D
# 2  Bill    Jones  A

# %%
pd.DataFrame(names, columns=['first','last','middle'])
# Out:
#   first     last middle
# 0  Paul     Boal      E
# 1  Eric  Westhus      D
# 2  Bill    Jones      A

# %%
data = pd.DataFrame(names, columns=['first','last','middle'])

# %%
data['first']
# Out:
# 0    Paul
# 1    Eric
# 2    Bill
# Name: first, dtype: object

# %%
data.size
# Out:
# 9

# %%
first_names = ['Paul','Eric','Bill']
middle_names = ['E','D','A']
last_names = ['Boal','Westhus','Jones']

# %%
list(zip(first_names, middle_names, last_names))
# Out:
# [('Paul', 'E', 'Boal'), ('Eric', 'D', 'Westhus'), ('Bill', 'A', 'Jones')]

# %%
pd.DataFrame(list(zip(first_names, middle_names, last_names)),
             columns=['first','middle','last'])
# Out:
#   first middle     last
# 0  Paul      E     Boal
# 1  Eric      D  Westhus
# 2  Bill      A    Jones

# %%
people = [
    { 'first': 'Paul', 'last': 'Boal', 'middle': 'E' },
    { 'first': 'Eric', 'last': 'Westhus', 'middle': 'D'},
    { 'first': 'Bill', 'last': 'Jones', 'middle': 'A'}
]

# %%
pd.DataFrame(people)
# Out:
#   first     last middle
# 0  Paul     Boal      E
# 1  Eric  Westhus      D
# 2  Bill    Jones      A

# %%
people = [
    { 'first': 'Paul', 'last': 'Boal', 'middle': 'E' },
    { 'first': 'Eric', 'last': 'Westhus', 'middle': 'D'},
    {  'last': 'Jones', 'first': 'Bill'}
]

# %%
pd.DataFrame(people)
# Out:
#   first     last middle
# 0  Paul     Boal      E
# 1  Eric  Westhus      D
# 2  Bill    Jones    NaN

# %%
import pandas as pd
people = [
    { 'first': 'Paul', 'last': 'Boal', 'middle': 'E' },
    { 'first': 'Eric', 'last': 'Westhus', 'middle': 'D'},
    { 'first': 'Bill', 'last': 'Jones', 'middle': 'A'},
    { 'first': 'Walter', 'last': 'Cronkite'},
    { 'first': 'Eddie', 'last': 'Murphy'},
    { 'first': 'Cher'}
]
pd.DataFrame(people)
# Out:
#     first      last middle
# 0    Paul      Boal      E
# 1    Eric   Westhus      D
# 2    Bill     Jones      A
# 3  Walter  Cronkite    NaN
# 4   Eddie    Murphy    NaN
# 5    Cher       NaN    NaN

# %%
visits = pd.read_csv('https://hds5210-data.s3.amazonaws.com/visits.csv')

# %%
visits
# Out:
#     SYSTEM          HOSPITAL PATIENT_ID  PATIENT_AGE BILLING_CODE  \
# 0    Mercy  Missouri Baptist     E74109           39        97140
# 1      BJC        SSM DePaul     E29207           40        97140
# 2      SSM      SLU Hospital     E37839           33        G0283
# 3      SSM   Mercy St. Louis     E45853           65        G0283
# 4      SSM      SLU Hospital     E14769           48        97140
# ..     ...               ...        ...          ...          ...
# 195    SSM  Missouri Baptist     E61327           52        97140
# 196    SSM      SLU Hospital     E13076           42        97140
# 197  Mercy     Barnes Jewish     E72890           36        97140
# 198  Mercy        SSM DePaul     E82016           66        97140
# 199    SSM        SSM DePaul     E26182           36        G0283
#
#      SERVICE_CODE  VISIT_DATE
# 0              12  2021-05-01
# 1              11  2021-03-25
# 2              11  2021-07-25
# 3              12  2021-07-27
# ...

# %%
len(visits)
# Out:
# 200

# %%
visits.shape
# Out:
# (200, 7)

# %%
visits['PATIENT_AGE'].mean()
# Out:
# 52.125

# %%
visits['PATIENT_AGE'].max()
# Out:
# 75

# %%
visits.dtypes
# Out:
# SYSTEM          object
# HOSPITAL        object
# PATIENT_ID      object
# PATIENT_AGE      int64
# BILLING_CODE    object
# SERVICE_CODE     int64
# VISIT_DATE      object
# dtype: object

# %%
pd.read_json('https://hds5210-data.s3.amazonaws.com/negotiated_rates.json')
# Out:
#               reporting_entity_name      reporting_entity_type  \
# 0  United HealthCare Services, Inc.  Third-Party Administrator
# 1  United HealthCare Services, Inc.  Third-Party Administrator
# 2  United HealthCare Services, Inc.  Third-Party Administrator
# 3  United HealthCare Services, Inc.  Third-Party Administrator
# 4  United HealthCare Services, Inc.  Third-Party Administrator
# 5  United HealthCare Services, Inc.  Third-Party Administrator
#
#   last_updated_on version                                     out_of_network
# 0      2022-10-01   1.0.0  {'name': 'E-STIM 1/> AREAS OTH THAN WND CARE P...
# 1      2022-10-01   1.0.0  {'name': 'MANUAL THERAPY TQS 1/> REGIONS EACH ...
# 2      2022-10-01   1.0.0  {'name': 'SBSQ HOSPITAL CARE/DAY 25 MINUTES', ...
# 3      2022-10-01   1.0.0  {'name': 'SBSQ HOSPITAL CARE/DAY 35 MINUTES', ...
# 4      2022-10-01   1.0.0  {'name': 'THER PX 1/> AREAS EACH 15 MIN NEUROM...
# ...

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/List_of_world_cities_by_population_density')

# %%
len(dfs)
# Out:
# 1

# %%
type(dfs)
# Out:
# list

# %%
dfs[0]
# Out:
#                        City      Population     Area (km²) Area (mi²)  \
# 0                      Malé      153,904[1]       1.956[1]      0.755
# 1                    Manila    1,660,714[2]       38.55[3]      14.88
# 2                     Bogor      866,034[4]       21.56[5]       8.32
# 3                  Titagarh      124,213[6]        3.24[7]       1.25
# 4                 Baranagar      250,768[6]        7.12[7]       2.75
# 5                 Serampore      197,857[6]        5.88[7]       2.27
# 6              South Dumdum      392,444[6]       13.54[7]       5.23
# 7                 Kamarhati      314,507[6]       10.96[7]       4.23
# 8                   Kolkata    5,138,208[8]         185[9]       71.4
# 9          Levallois-Perret      66,082[10]       2.41[10]       0.93
# 10              Mandaluyong      305,576[2]       11.26[3]       4.35
# 11                  Neapoli      30,279[11]       1.17[11]       0.45
# ...

# %%
data = pd.read_excel(
    'https://hds5210-data.s3.amazonaws.com/bhmclr_drg.xlsx', sheet_name='Sheet1',
    skiprows=3
)

# %%
data
# Out:
#               Location Code Type                      Code  NDC  Rev Code  \
# 0     BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 013  NaN       NaN
# 1     BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 022  NaN       NaN
# 2     BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 024  NaN       NaN
# 3     BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 025  NaN       NaN
# 4     BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 026  NaN       NaN
# ...                ...       ...                       ...  ...       ...
# 3859  BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 987  NaN       NaN
# 3860  BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 988  NaN       NaN
# 3861  BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 989  NaN       NaN
# 3862  BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 998  NaN       NaN
# 3863  BHMC LITTLE ROCK       DRG  MS-DRG V38 (FY 2021) 999  NaN       NaN
#
#      Procedure                              Procedure Description  Quantity  \
# ...

# %%
data.columns
# Out:
# Index(['Location', 'Code Type', 'Code', 'NDC', 'Rev Code', 'Procedure',
#        'Procedure Description', 'Quantity', 'Payer', 'IP Charge',
#        'IP Expected Reimbursement', 'MIN_IP_XR', 'MAX_IP_XR', 'IP Cash Price',
#        'OP Charge', 'OP Expected Reimbursement', 'MIN_OP_XR', 'MAX_OP_XR',
#        'OP Cash Price'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Location                      object
# Code Type                     object
# Code                          object
# NDC                          float64
# Rev Code                     float64
# Procedure                     object
# Procedure Description         object
# Quantity                       int64
# Payer                         object
# IP Charge                    float64
# IP Expected Reimbursement    float64
# MIN_IP_XR                    float64
# MAX_IP_XR                    float64
# IP Cash Price                float64
# OP Charge                      int64
# OP Expected Reimbursement    float64
# MIN_OP_XR                    float64
# MAX_OP_XR                    float64
# OP Cash Price                float64
# dtype: object
